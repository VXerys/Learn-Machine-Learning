# %%
import pandas as pd

# %% [markdown]
# ### Series
#  a 1-dimensional column of data

# %%
# create a series of car types
cars = pd.Series(["Toyota","Honda","BMW"])
cars
# Out:
# 0    Toyota
# 1     Honda
# 2       BMW
# dtype: object

# %%
# creating a series of colours
colours = pd.Series(["White","Black","Blue"])
colours
# Out:
# 0    White
# 1    Black
# 2     Blue
# dtype: object

# %% [markdown]
# ### DataFrame
# a 2-dimensional table of data with rows and columns

# %%
# Creating a DataFrame if cars and colours
car_data = pd.DataFrame({"Car Type": cars,
                         "Colour": colours})
car_data
# Out:
#   Car Type Colour
# 0   Toyota  White
# 1    Honda  Black
# 2      BMW   Blue

# %% [markdown]
# ### Exercises
# 1. Make a Series of different foods.
# 2. Make a Series of different dollar values (these can be integers).
# 3. Combine your Series's of foods and dollar values into a DataFrame.

# %%
foods = pd.Series(["Chicken", "Pizza","Burgers"])
foods
# Out:
# 0    Chicken
# 1      Pizza
# 2    Burgers
# dtype: object

# %%
price = pd.Series([120,89,75])
price
# Out:
# 0    120
# 1     89
# 2     75
# dtype: int64

# %%
food_data = pd.DataFrame({"Foods": foods,
                          "Price": price})
food_data
# Out:
#      Foods  Price
# 0  Chicken    120
# 1    Pizza     89
# 2  Burgers     75

# %%
# import dataset pokemon dengan read_csv.
pokemon_data = pd.read_csv("Pokemon.csv")
pokemon_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
# Export data
pokemon_data.to_csv("backup-pokemon-data.csv")

# %%
# Latihan import
AI_data = pd.read_csv("artificial-intelligence-training-computation.csv")
AI_data
# Out:
#                                        Entity  Code         Day  \
# 0    (ensemble): AWD-LSTM-DOC (fin) × 5 (WT2)   NaN  2018-08-30
# 1      2-layer-LSTM+Deep-Gradient-Compression   NaN  2017-12-05
# 2                      3D city reconstruction   NaN  2009-09-29
# 3                       4 layer QRNN (h=2500)   NaN  2018-03-22
# 4                                6-Act Tether   NaN  2021-08-03
# ..                                        ...   ...         ...
# 832                                   mT5-XXL   NaN  2020-10-20
# 833                top-down frozen classifier   NaN  2021-02-09
# 834                        wave2vec 2.0 LARGE   NaN  2020-10-22
# 835                          xTrimoPGLM -100B   NaN  2023-07-06
# 836                                    λ-WASP   NaN  2007-06-01
#
#      Training computation (petaFLOP)    Domain
# 0                       6.930000e+02  Language
# 1                       1.340000e+00  Language
# 2                                NaN     Other
# 3                       2.400000e+02  Language
# 4                                NaN     Other
# ..                               ...       ...
# 832                     8.200000e+07  Language
# 833                              NaN  Language
# 834                     1.900000e+06    Speech
# 835                     6.000100e+08   Biology
# 836                              NaN  Language
#
# [837 rows x 5 columns]

# %%
# Latihan Export
AI_data.to_csv("backup_data_ai.csv")

# %%
pokemon_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
# .dtypes shows us what datatype each column contains.
pokemon_data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# .describe() gives you a quick statistical overview of the numerical columns.
pokemon_data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %%
# .info() shows a handful of useful information about a DataFrame such as:

# How many entries (rows) there are
# Whether there are missing values (if a columns non-null value is less than the number of entries,
# it has missing values).
# The datatypes of each column
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pokemon_data.mean(numeric_only=True)
# Out:
# #             362.81375
# Total         435.10250
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
pokemon_data.sum(numeric_only=True)
# Out:
# #             290251
# Total         348082
# HP             55407
# Attack         63201
# Defense        59074
# Sp. Atk        58256
# Sp. Def        57522
# Speed          54622
# Generation      2659
# Legendary         65
# dtype: int64

# %%
pokemon_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
# .columns will show you all the columns of a DataFrame.
pokemon_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# .index will show you the values in a DataFrame's index (the column on the far left).
pokemon_data.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
len(pokemon_data)
# Out:
# 800

# %%
# Displays the first n rows of a DataFrame
pokemon_data.head(n=10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
# Displays the last n rows of a DataFrame
pokemon_data.tail(n=5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
# .loc[] takes an integer or label as input. And it chooses from your Series or DataFrame whichever index matches the number.
pokemon_data.loc[:,'Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# iloc[] does a similar thing but works with exact positions.
pokemon_data.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %% [markdown]
# ### When should you use .loc[] or .iloc[]?
#
# - Use .loc[] when you're selecting rows and columns based on their lables or a condition (e.g. retrieving data for specific columns).
# - Use .iloc[] when you're selecting rows and columns based on their integer index positions (e.g. extracting the first ten rows regardless of the labels).
#
# However, in saying this, it will often take a bit of practice with each of the methods before you figure out which you'd like to use.

# %%
# Selects the column named 'Name' from the DataFrame.
pokemon_data["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Creates a line plot of a DataFrame's columns
pokemon_data.plot()
# Out:
# <Axes: >

# %%
pokemon_data.hist()
# Out:
# array([[<Axes: title={'center': '#'}>, <Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'HP'}>],
#        [<Axes: title={'center': 'Attack'}>,
#         <Axes: title={'center': 'Defense'}>,
#         <Axes: title={'center': 'Sp. Atk'}>],
#        [<Axes: title={'center': 'Sp. Def'}>,
#         <Axes: title={'center': 'Speed'}>,
#         <Axes: title={'center': 'Generation'}>]], dtype=object)

# %%
# .head() allows you to view the first 5 rows of your DataFrame. You'll likely be using this one a lot.
pokemon_data.head(6)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
animal_data = pd.Series(["Panda", "Tiger", "Cat", "Bird", "Lion"], index=[1, 34, 3, 50, 23])
animal_data
# Out:
# 1     Panda
# 34    Tiger
# 3       Cat
# 50     Bird
# 23     Lion
# dtype: object

# %%
# Select name pokemon Charmeleon
pokemon_data[pokemon_data["Name"] == "Charmeleon"]
# Out:
#    #        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 5  5  Charmeleon   Fire    NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 5     80           1      False

# %%
# Mencari nama pokemon yang memiliki attack tinggi
pokemon_data.plot(x="Name", y="Attack");

# %%
pokemon_data["Attack"].hist()
# Out:
# <Axes: >

# %%
pokemon_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
# Mengubah semua attack menjadi 100
pokemon_data["Attack"] = 100
pokemon_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45     100       49
# 1      2                Ivysaur    Grass  Poison    405  60     100       63
# 2      3               Venusaur    Grass  Poison    525  80     100       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39     100       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     100      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     100       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     100       60
# 799  721              Volcanion     Fire   Water    600  80     100      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
pokemon_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]
